# %%
""" 
Programa adultos
Definição: pergunta a idade e se for maior de 18 imprime na tela
Autor: Eduardo M
Data: 24/03/2026
Versão: 0.0.1
"""
# Out:
# ' \nPrograma adultos\nDefinição: pergunta a idade e se for maior de 18 imprime na tela\nAutor: Eduardo M\nData: 24/03/2026\nVersão: 0.0.1\n'

# %%
# Alocação de memória
idade = 0
texto = "Oi você é adulto"

# %%
# Entrada de dados
idade =  int(input("\nQual a sua idade?: "))
# Out:
# Qual a sua idade?:  19

# %%
# Processamento
if idade > 18:
    print("Oi, você é adulto")
# Out:
# Oi, você é adulto

# %%
# Saída
print("texto")
# Out:
# texto
